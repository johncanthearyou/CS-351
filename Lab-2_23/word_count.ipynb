# %%
# %%file word_count.py
# From http://mrjob.readthedocs.org/en/latest/guides/quickstart.html#writing-your-first-job

from mrjob.job import MRJob
from mrjob.step import MRStep
import re

class MRWordFrequencyCount(MRJob):
    def steps(self):
        return [
            # Step 1: Count bigrams
            MRStep(mapper=self.mapper_counts,
                   reducer=self.reducer_counts),
            # Step 2: Calculate probabilities
            MRStep(reducer=self.reducer_prob)
        ]

    # Step 1a: Split out all bigrams
    def mapper_counts(self, _, line):
        words = re.findall('([a-zA-Z]+[\'][a-zA-Z]+|[a-zA-Z]+)', line)
        num_words = len(words)
        if num_words>1:
            words[0] = words[0].upper()
            for i in range(num_words-1):
                words[i+1] = words[i+1].upper()
                yield (words[i], words[i+1]), 1

    # Step 1b: Reduce bigram counts
    def reducer_counts(self, words, count):
        word1, word2 = words
        yield word1, (sum(count),word2)

    
    # Step 2: Calculate probablities for each bigram
    #         and get top words that come after 'my'
    def reducer_prob(self, word1, bigrams_gen):
        yield word1, bigrams_gen

if __name__ == '__main__':
    MRWordFrequencyCount.run()
# Out:
# Overwriting word_count.py

# %%
# !python word_count.py -r emr s3://jws-mapreduce/Input/ \
--output-dir=s3://jws-mapreduce/result \
--no-output
# Out:
# Using configs in /Users/johnstocktoniv/.mrjob.conf
# Using s3://mrjob-22bfba3f9ba9c6ea/tmp/ as our temp dir on S3
# Creating temp directory /var/folders/5s/hq_d6y217wb9tt3p5v4_25cw0000gn/T/word_count.johnstocktoniv.20220311.100709.361835
# uploading working dir files to s3://mrjob-22bfba3f9ba9c6ea/tmp/word_count.johnstocktoniv.20220311.100709.361835/files/wd...
# Copying other local files to s3://mrjob-22bfba3f9ba9c6ea/tmp/word_count.johnstocktoniv.20220311.100709.361835/files/
# Created new cluster j-W9QAGRIZT73H
# Added EMR tags to cluster j-W9QAGRIZT73H: __mrjob_label=word_count, __mrjob_owner=johnstocktoniv, __mrjob_version=0.7.4
# Waiting for Step 1 of 2 (s-2GEAYZCZFCTPL) to complete...
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   PENDING (cluster is STARTING: Configuring cluster software)
#   master node is ec2-34-230-84-16.compute-1.amazonaws.com
#   Connect to resource manager at: http://localhost:40335/cluster
#   PENDING (cluster is RUNNING: Running step)
#   PENDING (cluster is RUNNING: Running step)
#   RUNNING for 0:01:07
#   COMPLETED
# Attempting to fetch counters from logs...
# Looking for step log in /mnt/var/log/hadoop/steps/s-2GEAYZCZFCTPL on ec2-34-230-84-16.compute-1.amazonaws.com...
# Looking for step log in s3://mrjob-22bfba3f9ba9c6ea/tmp/logs/j-W9QAGRIZT73H/steps/s-2GEAYZCZFCTPL...
#   Parsing step log: s3://mrjob-22bfba3f9ba9c6ea/tmp/logs/j-W9QAGRIZT73H/steps/s-2GEAYZCZFCTPL/syslog.gz
# Counters: 60
# 	File Input Format Counters
# 		Bytes Read=24098463
# 	File Output Format Counters
# 		Bytes Written=18791339
# 	File System Counters
# 		FILE: Number of bytes read=10861204
# 		FILE: Number of bytes written=26242316
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=364
# 		HDFS: Number of bytes read erasure-coded=0
# 		HDFS: Number of bytes written=18791339
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=13
# 		HDFS: Number of write operations=2
# 		S3: Number of bytes read=24098463
# 		S3: Number of bytes written=0
# 		S3: Number of large read operations=0
# 		S3: Number of read operations=0
# 		S3: Number of write operations=0
# 	Job Counters
# 		Data-local map tasks=4
# 		Killed map tasks=1
# 		Launched map tasks=4
# 		Launched reduce tasks=1
# 		Total megabyte-milliseconds taken by all map tasks=212791296
# 		Total megabyte-milliseconds taken by all reduce tasks=163510272
# 		Total time spent by all map tasks (ms)=69268
# 		Total time spent by all maps in occupied slots (ms)=6649728
# 		Total time spent by all reduce tasks (ms)=26613
# 		Total time spent by all reduces in occupied slots (ms)=5109696
# 		Total vcore-milliseconds taken by all map tasks=69268
# 		Total vcore-milliseconds taken by all reduce tasks=26613
# 	Map-Reduce Framework
# 		CPU time spent (ms)=97610
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=1075
# 		Input split bytes=364
# 		Map input records=231658
# 		Map output bytes=73399393
# 		Map output materialized bytes=14174481
# 		Map output records=3811933
# 		Merged Map outputs=4
# 		Peak Map Physical memory (bytes)=773017600
# 		Peak Map Virtual memory (bytes)=4690440192
# 		Peak Reduce Physical memory (bytes)=462389248
# 		Peak Reduce Virtual memory (bytes)=7335403520
# 		Physical memory (bytes) snapshot=2975051776
# 		Reduce input groups=874906
# 		Reduce input records=3811933
# 		Reduce output records=874906
# 		Reduce shuffle bytes=14174481
# 		Shuffled Maps =4
# 		Spilled Records=7623866
# 		Total committed heap usage (bytes)=2808610816
# 		Virtual memory (bytes) snapshot=24896909312
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# Terminating cluster: j-W9QAGRIZT73H
# Traceback (most recent call last):
#   File "/Users/johnstocktoniv/SchoolDrive/JuniorII/CS-351/Work/Lab-2_23/word_count.py", line 53, in <module>
#     MRWordFrequencyCount.run()
#   File "/usr/local/lib/python3.9/site-packages/mrjob/job.py", line 616, in run
#     cls().execute()
#   File "/usr/local/lib/python3.9/site-packages/mrjob/job.py", line 687, in execute
#     self.run_job()
#   File "/usr/local/lib/python3.9/site-packages/mrjob/job.py", line 636, in run_job
#     runner.run()
#   File "/usr/local/lib/python3.9/site-packages/mrjob/runner.py", line 503, in run
#     self._run()
#   File "/usr/local/lib/python3.9/site-packages/mrjob/emr.py", line 705, in _run
#     self._finish_run()
#   File "/usr/local/lib/python3.9/site-packages/mrjob/emr.py", line 710, in _finish_run
#     self._wait_for_steps_to_complete()
#   File "/usr/local/lib/python3.9/site-packages/mrjob/emr.py", line 1570, in _wait_for_steps_to_complete
#     self._add_steps_to_cluster(
#   File "/usr/local/lib/python3.9/site-packages/mrjob/emr.py", line 1537, in _add_steps_to_cluster
#     step_ids = emr_client.add_job_flow_steps(**steps_kwargs)['StepIds']
#   File "/usr/local/lib/python3.9/site-packages/mrjob/retry.py", line 108, in call_and_maybe_retry
#     return f(*args, **kwargs)
#   File "/usr/local/lib/python3.9/site-packages/botocore/client.py", line 391, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#   File "/usr/local/lib/python3.9/site-packages/botocore/client.py", line 719, in _make_api_call
#     raise error_class(parsed_response, operation_name)
# botocore.exceptions.ClientError: An error occurred (ValidationException) when calling the AddJobFlowSteps operation: A job flow that is shutting down, terminated, or finished may not be modified.
